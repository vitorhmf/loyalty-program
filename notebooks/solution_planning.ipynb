# %% [markdown]
# # Solution Planning

# %%
from IPython.display        import Image

# %% [markdown]
# ### Input

# %% [markdown]
# * Business Problem: selecionar os clientes mais valiosos para integrar um programa de fidelização
#
# * Conjunto de dados: vendas de um e-commerce online, durante 1 ano

# %% [markdown]
# ### Output

# %% [markdown]
# * Indicação das pessoas que farão parte do programa Insiders.
# * Relatório com as respostas das perguntas de negócio.

# %% [markdown]
# ### Task

# %% [markdown]
# 1. Quem são as pessoas elegíveis para participar do programa de Insiders ?
#     - O que é ser elegível? O que são clientes de maior valor?
#         - Faturamento:
#             - alto ticket médio
#             - alto LTV (long time value = quanto o cliente gasta na empresa)
#             - baixa recência (pequeno intervalo entre a última compra)
#             - alto basket size (carrinho com muitos produtos)
#             - baixa probabilidade de churn (pode ser levantada em um modelo de classificação)
#             - alta previsão de LTV
#             - alta propensão de compra
#         - Custo:
#             - baixa taxa de devolução
#         - Experiência de compra:
#             - média alta das avaliações

# %% [markdown]
# 2. Quantos clientes farão parte do grupo?
#     - total de clientes
#     - clientes selecionados
#     - % de clientes no programa

# %% [markdown]
# 3. Quais as principais características desses clientes ? (ideal para prospectar clientes parecidos)
#     - idade
#     - genero
#     - localização
#     - perfil de consumo

# %% [markdown]
# 4. Qual a porcentagem de contribuição do faturamento vinda do Insiders ?
#     - faturamento total do ano
#     - faturamento do grupo insiders

# %% [markdown]
# 5. Qual a expectativa de faturamento desse grupo para os próximos meses ?
#     - LTV do grupo
#     - Analise de cohort (marcação do cliente para acompanhar a evolução das suas compras.)

# %% [markdown]
# 6. Quais as condições para uma pessoa ser elegível ao Insiders ?
#     - definir periodicidade (1 mes, 3 meses, etc)
#     - a pessoa precisa ser similar com as pessoas do grupo

# %% [markdown]
# 7. Quais as condições para uma pessoa ser removida do Insiders ?
#     - definir periodicidade (1 mes, 3 meses, etc)
#     - a pessoa precisa ser diferente das pessoas do grupo

# %% [markdown]
# 8. Qual a garantia que o programa Insiders é melhor que o restante da base ?
#     - teste A/B
#     - teste A/B Bayesiano
#     - Teste de hipoteses

# %% [markdown]
# 9. Quais ações o time de marketing pode realizar para aumentar o faturamento?
#     - desconto
#     - preferência de compra
#     - visita a empresa

# %% [markdown]
# ### Research Desk

# %% [markdown]
# * Modelo RFM (Recency, Frequency, Monetary)
#     - modelo simples para dar uma primeira visão do problema (baseline), útil para modelos de negócios que tem vendas recorrentes
#     - ordena a base de clientes por cada um dos parametros e gera um score para cada um
#     - calcula a média das notas dos 3 parametros e classifica a lista por essa medida

# %%
Image('../image/rfm_segmentation.png', width=800)
